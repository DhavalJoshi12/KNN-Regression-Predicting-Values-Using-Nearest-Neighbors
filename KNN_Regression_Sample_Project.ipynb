# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#load data
Data = pd.read_csv('/content/house_price_cwh.csv')
Data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
#clean data
Data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
Data.dropna()
Data = Data.dropna()
Data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [501 rows x 14 columns]

# %%
Data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#we will convert data into input and output
X = Data.drop(columns=['MEDV'])
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [501 rows x 13 columns]

# %%
y = Data[['MEDV']]
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [501 rows x 1 columns]

# %%
#reduce the differnce in input data by standard scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X = pd.DataFrame(X)
X
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.421957  0.282068 -1.292009 -0.274057 -0.147765  0.412351 -0.117562
# 1   -0.419525 -0.487464 -0.597147 -0.274057 -0.742232  0.193874  0.368529
# 2   -0.419527 -0.487464 -0.597147 -0.274057 -0.742232  1.277743 -0.263034
# 3   -0.418938 -0.487464 -1.310986 -0.274057 -0.837002  1.012451 -0.805895
# 4   -0.414687 -0.487464 -1.310986 -0.274057 -0.837002  1.223834 -0.507854
# ..        ...       ...       ...       ...       ...       ...       ...
# 496 -0.415431 -0.487464  0.112314 -0.274057  0.153777  0.437887  0.020814
# 497 -0.417443 -0.487464  0.112314 -0.274057  0.153777 -0.233147  0.290470
# 498 -0.415648 -0.487464  0.112314 -0.274057  0.153777  0.981240  0.797849
# 499 -0.409989 -0.487464  0.112314 -0.274057  0.153777  0.723041  0.737532
# 500 -0.417195 -0.487464  0.112314 -0.274057  0.153777 -0.360828  0.435943
#
#            7         8         9         10        11        12
# 0    0.144476 -0.985106 -0.670074 -1.457141  0.443342 -1.071016
# 1    0.561899 -0.870516 -0.989880 -0.301961  0.443342 -0.489652
# 2    0.561899 -0.870516 -0.989880 -0.301961  0.398900 -1.203779
# 3    1.083071 -0.755926 -1.108327  0.113904  0.418555 -1.356107
# 4    1.083071 -0.755926 -1.108327  0.113904  0.443342 -1.022103
# ..        ...       ...       ...       ...       ...       ...
# 496 -0.622409 -0.985106 -0.806288  1.176670  0.389728 -0.415584
# 497 -0.713356 -0.985106 -0.806288  1.176670  0.443342 -0.498037
# 498 -0.770466 -0.985106 -0.806288  1.176670  0.443342 -0.978780
# 499 -0.665098 -0.985106 -0.806288  1.176670  0.405670 -0.861389
# 500 -0.609845 -0.985106 -0.806288  1.176670  0.443342 -0.665738
#
# [501 rows x 13 columns]

# %%
#train_test_split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split (X,y,train_size = 0.8 , random_state=42)

# %%
#model making
from sklearn.neighbors import KNeighborsRegressor
Model = KNeighborsRegressor(n_neighbors=5)

# %%
Model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
#now we will predict the value
y_pred = Model.predict(X_test)
y_pred
# Out:
# array([[17.86],
#        [22.1 ],
#        [ 8.46],
#        [27.64],
#        [21.34],
#        [ 9.86],
#        [11.92],
#        [19.34],
#        [23.52],
#        [14.18],
#        [21.12],
#        [29.62],
#        [11.46],
#        [25.04],
#        [14.24],
#        [12.3 ],
#        [21.7 ],
#        [17.68],
#        [23.16],
#        [ 9.8 ],
#        [18.9 ],
#        [20.2 ],
#        [24.38],
#        [19.32],
#        [24.12],
#        [16.18],
#        [21.7 ],
#        [22.6 ],
#        [19.74],
#        [19.76],
#        [24.  ],
#        [29.52],
#        [15.96],
#        [26.18],
#        [33.2 ],
#        [21.  ],
#        [11.06],
#        [24.58],
#        [20.46],
#        [22.84],
#        [12.34],
#        [43.22],
#        [16.52],
#        [32.94],
#        [13.54],
#        [26.5 ],
#        [23.96],
#        [21.56],
#        [14.78],
#        [14.04],
#        [24.42],
#        [30.06],
#        [16.  ],
#        [12.36],
#        [32.58],
#        [30.04],
#        [17.04],
#        [19.12],
#        [21.32],
#        [25.32],
#        [19.62],
#        [43.84],
#        [21.04],
#        [15.82],
#        [24.02],
#        [24.76],
#        [14.2 ],
#        [17.54],
#        [23.58],
#        [15.04],
#        [31.46],
#        [20.92],
#        [31.04],
#        [23.78],
#        [21.6 ],
#        [20.26],
#        [31.04],
#        [24.58],
#        [18.84],
#        [20.58],
#        [24.42],
#        [25.48],
#        [21.06],
#        [24.18],
#        [22.72],
#        [26.06],
#        [26.3 ],
#        [13.86],
#        [19.2 ],
#        [39.74],
#        [10.1 ],
#        [13.96],
#        [16.78],
#        [26.14],
#        [10.54],
#        [22.58],
#        [29.  ],
#        [22.68],
#        [12.64],
#        [22.04],
#        [23.14]])

# %%
#accuracy
from sklearn.metrics import r2_score
print (r2_score(y_pred,y_test))
# Out:
# 0.746356814545406

# %%
#our model is 74.63%
